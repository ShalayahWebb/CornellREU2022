# %%
import pandas as pd

# %%
df = pd.read_excel("0617_300Microns.xlsx")
df
# Out:
#     Cab.Bridge  Voltage steps  V(PZT)  Real_V  M-E Sensor  ME_D  ME_A_dis  \
# 0        30467            NaN  -0.450   -4.50      284.46   NaN       NaN
# 1        30867          400.0  -1.744  -17.44      291.18  6.72    291.18
# 2        31267          400.0  -2.766  -27.66      297.91  6.73    297.91
# 3        31277           10.0  -3.102  -31.02         NaN   NaN       NaN
# 4        29604            NaN  -0.412   -4.12         NaN   NaN       NaN
# 5        29804          200.0   0.703    7.03      273.49   NaN       NaN
# 6        30204          400.0   2.293   22.93      280.13  6.64      6.64
# 7        30604          400.0   2.875   28.75      286.81  6.68     13.32
# 8        31004          400.0   3.164   31.64      293.54  6.73     20.05
# 9        31404          400.0   3.608   36.08      300.27  6.73     26.78
# 10       31804          400.0   3.860   38.60      307.04  6.77     33.55
# 11       32204          400.0   4.310   43.10      313.82  6.78     40.33
# 12       32604          400.0   4.860   48.60      320.65  6.83     47.16
# 13       33004          400.0   5.280   52.80      327.60  6.95     54.11
# 14       33404          400.0   5.900   59.00      335.66  8.06     62.17
# 15       33804          400.0   6.680   66.80      343.78  8.12     70.29
# 16       34204          400.0   7.490   74.90      351.92  8.14     78.43
# 17       33804            NaN   5.900   59.00      343.80 -8.12     70.31
# 18       33404         -400.0   4.730   47.30      335.67 -8.13     62.18
# 19       33004         -400.0   3.690   36.90      327.62 -8.05     54.13
# 20       32604         -400.0   2.892   28.92      320.67 -6.95     47.18
# 21       32204         -400.0   2.134   21.34      313.85 -6.82     40.36
# 22       31804         -400.0   1.428   14.28      307.07 -6.78     33.58
# 23       31404         -400.0   0.862    8.62      303.30 -3.77     29.81
# 24       31004         -400.0   0.203    2.03      293.57 -9.73     20.08
# 25       30604         -400.0  -0.392   -3.92      286.85 -6.72     13.36
# 26       30204         -400.0  -1.030  -10.30      280.18 -6.67      6.69
#
#     Fringes  fringe_D  Fringe_A_dis      Time
# 0       NaN       NaN           NaN  10:15:00
# 1      20.0    6.3280           NaN  10:20:00
# 2      18.0    5.6952       12.0232  10:27:00
# 3       NaN       NaN           NaN       NaN
# 4       NaN       NaN           NaN       NaN
# 5       NaN       NaN           NaN  11:02:00
# 6      21.0    6.6444           NaN  11:07:00
# 7      19.0    6.0116       12.6560  11:12:00
# 8      11.0    3.4804       16.1364  11:14:00
# 9      21.0    6.6444       22.7808  11:18:00
# 10     21.0    6.6444       29.4252  11:22:00
# 11     22.0    6.9608       36.3860  11:24:00
# 12     22.0    6.9608       43.3468  11:28:00
# 13     11.0    3.4804       46.8272  11:30:00
# 14     21.0    6.6444       53.4716  11:34:00
# 15     23.0    7.2772       60.7488  11:39:00
# 16     23.0    7.2772       68.0260  11:43:00
# 17    -19.0   -6.0116       62.0144  11:51:00
# 18    -24.0   -7.5936       54.4208  11:53:00
# 19    -24.0   -7.5936       46.8272  11:55:00
# 20    -21.0   -6.6444       40.1828  11:58:00
# 21    -21.0   -6.6444       33.5384  12:01:00
# 22    -22.0   -6.9608       26.5776  12:04:00
# 23    -19.0   -6.0116       20.5660  12:06:00
# 24    -20.0   -6.3280       14.2380  12:15:00
# 25    -21.0   -6.6444        7.5936  12:18:00
# 26    -20.0   -6.3280        1.2656  12:21:00

# %%
#indexing ME accumulated displacement column and row
ME_A_dis = df["ME_A_dis"][7:27]
print(ME_A_dis)
# Out:
# 7     13.32
# 8     20.05
# 9     26.78
# 10    33.55
# 11    40.33
# 12    47.16
# 13    54.11
# 14    62.17
# 15    70.29
# 16    78.43
# 17    70.31
# 18    62.18
# 19    54.13
# 20    47.18
# 21    40.36
# 22    33.58
# 23    29.81
# 24    20.08
# 25    13.36
# 26     6.69
# Name: ME_A_dis, dtype: float64

# %%
# indexing fringe dis. column
fringe_A_dis = df["Fringe_A_dis"][7:27]
print(fringe_A_dis)
# Out:
# 7     12.6560
# 8     16.1364
# 9     22.7808
# 10    29.4252
# 11    36.3860
# 12    43.3468
# 13    46.8272
# 14    53.4716
# 15    60.7488
# 16    68.0260
# 17    62.0144
# 18    54.4208
# 19    46.8272
# 20    40.1828
# 21    33.5384
# 22    26.5776
# 23    20.5660
# 24    14.2380
# 25     7.5936
# 26     1.2656
# Name: Fringe_A_dis, dtype: float64

# %%
# indexing PZT voltage column 
real_V = df["Real_V"][7:27]
print(real_V)
# Out:
# 7     28.75
# 8     31.64
# 9     36.08
# 10    38.60
# 11    43.10
# 12    48.60
# 13    52.80
# 14    59.00
# 15    66.80
# 16    74.90
# 17    59.00
# 18    47.30
# 19    36.90
# 20    28.92
# 21    21.34
# 22    14.28
# 23     8.62
# 24     2.03
# 25    -3.92
# 26   -10.30
# Name: Real_V, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.close("all")
#%matplotlib notebook makes the plot interactive
# %matplotlib notebook

# %%
import numpy as np

# %%
from scipy import stats

# %%
x = fringe_A_dis
y = ME_A_dis

# %%
info = stats.linregress(x,y)

# %%
print(info)
# Out:
# LinregressResult(slope=1.0782119591206054, intercept=3.6162390351865668, rvalue=0.9960070884902652, pvalue=2.414928007543171e-20, stderr=0.02277882641755961, intercept_stderr=0.9041385809092894)

# %%
#x error is 0.6
xerror = np.full_like(x,0.6)
yerror = np.full_like(y,0)

plt.scatter(x,y)

# plot of linear regression of data
plt.plot(x,x*info.slope+info.intercept,c = "green")

# plot of fringe displacement data, our "true" measurement
plt.plot(x,x,c = "red")

plt.errorbar(x,y,xerr=xerror,yerr=yerror,fmt = 'o',)



plt.xlabel('Accumulated Displacement Calculated from Fringes ($\mu m$)')
plt.ylabel('Accumulated Displacement Measured by Capacitive Sensor ($\mu m$)')
t = '300 $\mu m$ Capacitive Sensor Acc. Displacement vs. Fringe Count Acc. Displacement'
plt.text(-10, 85, t, ha='left', rotation=0, wrap=True)





plt.grid()
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(block=None)>

# %%
x = real_V
y = fringe_A_dis

plt.close("all")
plt.scatter(x,y)

plt.xlabel('Voltage (V)')
plt.ylabel('Acc. Displacement Calculated from Fringes ($\mu m$)')
plt.title('Acc. Fringe Count Displacement vs. PZT Voltage')



plt.grid()
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(block=None)>
