# %%
import pandas as pd
from matplotlib import pyplot as plt
from astropy.table import Table as Tb
# %matplotlib notebook

# %%
from scipy import stats
import numpy as np

# %%
# error = [0.13995085645586935,0.049347898674314966,0.046196250764090264]
# x = [300, 1000, 2000]
# y = [1.075265960989945,1.037682903400481, 0.9655774612900144]
# Before outlier rejection

error = [0.03713221679433509,0.049347898674314966,0.046196250764090264]
x = [300, 1000, 2000]
y = [1.0072894926286766,1.037682903400481, 0.9655774612900144]

# %%
plt.close("all")


plt.axhline(y = 1, color = 'r', linestyle = ':',label ="Slope = 1")

plt.xlabel('Range of Displacement ($\mu m$)')
plt.ylabel('Mean of Slopes')

t = '300 - 2000 $\mu m$ Mean of Each (D/Df) Slope vs. Range of Displacement'
plt.text(0, 1.42, t, ha='left', rotation=0, wrap=True)

plt.xlim(0, 2100)
plt.ylim(0.6, 1.4)

plt.errorbar(x, y,error, marker="o", markersize=5, markeredgecolor="green", markerfacecolor="green")
#plt.show()
#plt.plot(300,1.347171834435019,marker='o')

plt.grid()
plt.legend()
plt.show()

plt.savefig('300_2000_microns_means_slopes_plot_oneSensorwithoutoutlier.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">
